# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt
import statsmodels.api as sm
from patsy import dmatrices, dmatrix

# %%
iris = pd.read_csv('data/Iris.data')

# %% [markdown]
# # Iris setosa

# %%
iris_setosa = pd.DataFrame()

for key in iris.keys()[:-1]:
    iris_setosa[key] = iris[key]ºa

iris_setosa['is_setosa'] = [1 if species == 'Iris-setosa' else 0 for species in iris['species']]

# %%
sns.countplot(x='is_setosa', data=iris_setosa)

# %%
sns.scatterplot(x="sepal_length",y="sepal_width", hue ="is_setosa", data = iris_setosa, palette='hls')

# %%
sns.scatterplot(x="petal_length",y="petal_width", hue ="is_setosa", data = iris_setosa, palette='hls')

# %%
iris_setosa.groupby('is_setosa').mean()
# Out:
#            sepal_length  sepal_width  petal_length  petal_width
# is_setosa
# 0                 6.262        2.872         4.906        1.676
# 1                 5.006        3.418         1.464        0.244

# %%
pd.crosstab(iris_setosa.sepal_length, iris_setosa.is_setosa).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_setosa.petal_length, iris_setosa.is_setosa).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_setosa.sepal_width, iris_setosa.is_setosa).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_setosa.petal_width, iris_setosa.is_setosa).plot(kind='bar', stacked=True)

# %%
from patsy import dmatrices
y,X = dmatrices('is_setosa ~ sepal_length + sepal_width', data = iris_setosa, return_type = 'dataframe')

logit_model = sm.Logit(y,X)
result = logit_model.fit()
print(result.summary2())
# Out:
# ...
#          Current function value: 0.000000
#          Iterations: 35
#                               Results: Logit
# ...
# Model:                  Logit              Pseudo R-squared:   1.000
# Dependent Variable:     is_setosa          AIC:                6.0000
# Date:                   2019-02-24 20:53   BIC:                15.0319
# No. Observations:       150                Log-Likelihood:     -4.2709e-07
# Df Model:               2                  LL-Null:            -95.477
# Df Residuals:           147                LLR p-value:        3.4262e-42
# Converged:              0.0000             Scale:              1.0000
# No. Iterations:         35.0000
# --------------------------------------------------------------------------
#                Coef.     Std.Err.     z    P>|z|     [0.025       0.975]
# --------------------------------------------------------------------------
# Intercept     444.4242 465149.4366  0.0010 0.9992 -911231.7191 912120.5674
# ...

# %% [markdown]
# # Iris virginica

# %%
iris_virginica = pd.DataFrame()

for key in iris.keys()[:-1]:
    iris_virginica[key] = iris[key]

iris_virginica['is_virginica'] = [1 if species == 'Iris-virginica' else 0 for species in iris['species']]

# %%
sns.countplot(x='is_virginica', data=iris_virginica)

# %%
sns.scatterplot(x="sepal_length",y="sepal_width", hue ="is_virginica", data = iris_virginica, palette='hls')

# %%
sns.scatterplot(x="petal_length",y="petal_width", hue ="is_virginica", data = iris_virginica, palette='hls')

# %%
iris_setosa.groupby('is_setosa').mean()
# Out:
#            sepal_length  sepal_width  petal_length  petal_width
# is_setosa
# 0                 6.262        2.872         4.906        1.676
# 1                 5.006        3.418         1.464        0.244

# %%
pd.crosstab(iris_virginica.sepal_length, iris_virginica.is_virginica).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_virginica.petal_length, iris_virginica.is_virginica).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_virginica.sepal_width, iris_virginica.is_virginica).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_virginica.petal_width, iris_virginica.is_virginica).plot(kind='bar', stacked=True)

# %%
y,X = dmatrices('is_virginica ~ sepal_length + sepal_width + petal_length + petal_width', data = iris_virginica, return_type = 'dataframe')

logit_model = sm.Logit(y,X)
result = logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.039662
#          Iterations 14
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.938
# Dependent Variable: is_virginica     AIC:              21.8985
# Date:               2019-02-24 21:00 BIC:              36.9517
# No. Observations:   150              Log-Likelihood:   -5.9493
# Df Model:           4                LL-Null:          -95.477
# Df Residuals:       145              LLR p-value:      1.1894e-37
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     14.0000
# -----------------------------------------------------------------
#                  Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# -----------------------------------------------------------------
# Intercept       -42.6378  25.7077 -1.6586 0.0972 -93.0239  7.7483
# sepal_length     -2.4652   2.3943 -1.0296 0.3032  -7.1580  2.2275
# ...

# %%
iris['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Iris versicolor

# %%
iris_versicolor = pd.DataFrame()

for key in iris.keys()[:-1]:
    iris_versicolor[key] = iris[key]

iris_versicolor['is_versicolor'] = [1 if species == 'Iris-versicolor' else 0 for species in iris['species']]

# %%
sns.countplot(x='is_versicolor', data=iris_versicolor)

# %%
sns.scatterplot(x="sepal_length",y="sepal_width", hue ="is_versicolor", data = iris_versicolor, palette='hls')

# %%
sns.scatterplot(x="petal_length",y="petal_width", hue ="is_versicolor", data = iris_versicolor, palette='hls')

# %%
iris_versicolor.groupby('is_versicolor').mean()
# Out:
#                sepal_length  sepal_width  petal_length  petal_width
# is_versicolor
# 0                     5.797        3.196         3.508        1.135
# 1                     5.936        2.770         4.260        1.326

# %%
pd.crosstab(iris_versicolor.sepal_length, iris_versicolor.is_versicolor).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_versicolor.sepal_width, iris_versicolor.is_versicolor).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_versicolor.petal_length, iris_versicolor.is_versicolor).plot(kind='bar', stacked=True)

# %%
pd.crosstab(iris_versicolor.petal_width, iris_versicolor.is_versicolor).plot(kind='bar', stacked=True)

# %%
y,X = dmatrices('is_versicolor ~ sepal_length + sepal_width + petal_length + petal_width', data = iris_versicolor, return_type = 'dataframe')

logit_model = sm.Logit(y,X)
result = logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.485883
#          Iterations 6
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.237
# Dependent Variable: is_versicolor    AIC:              155.7649
# Date:               2019-02-24 21:07 BIC:              170.8180
# No. Observations:   150              Log-Likelihood:   -72.882
# Df Model:           4                LL-Null:          -95.477
# Df Residuals:       145              LLR p-value:      3.6313e-09
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     6.0000
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z     P>|z|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      7.3229    2.4980   2.9315  0.0034   2.4269  12.2189
# sepal_length  -0.2527    0.6495  -0.3892  0.6972  -1.5256   1.0202
# ...
